# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers=['kafka:9092'],
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

user_ids = [101, 102, 103, 104, 105]
admin_id=[101]
print("Starting Transaction Producer...")

for i in range(100):
    tx_data = {
        "tx_id": i,
        "userId": random.choice(user_ids),
        "amount": random.uniform(10.0, 10000.0), # >10000 triggers fraud
        "timestamp": time.time()
    }
    producer.send('fraud-detection', value=tx_data)
    print(f"Sent: {tx_data}")
    time.sleep(2)
# Out:
# Starting Transaction Producer...
# Sent: {'tx_id': 0, 'userId': 102, 'amount': 2080.92975906117, 'timestamp': 1781849937.4270356}
# Sent: {'tx_id': 1, 'userId': 102, 'amount': 4925.930955067524, 'timestamp': 1781849939.513553}
# Sent: {'tx_id': 2, 'userId': 105, 'amount': 9377.062666499023, 'timestamp': 1781849941.5144987}
# Sent: {'tx_id': 3, 'userId': 104, 'amount': 5752.913255873168, 'timestamp': 1781849943.5152645}
# Sent: {'tx_id': 4, 'userId': 101, 'amount': 1722.2570591436859, 'timestamp': 1781849945.515679}
# Sent: {'tx_id': 5, 'userId': 102, 'amount': 7849.914497481761, 'timestamp': 1781849947.5167434}
# Sent: {'tx_id': 6, 'userId': 105, 'amount': 3501.970968428682, 'timestamp': 1781849949.517315}
# Sent: {'tx_id': 7, 'userId': 105, 'amount': 4752.283351728383, 'timestamp': 1781849951.5171068}
# Sent: {'tx_id': 8, 'userId': 104, 'amount': 3870.740362253129, 'timestamp': 1781849953.517542}
# Sent: {'tx_id': 9, 'userId': 105, 'amount': 5414.540984080201, 'timestamp': 1781849955.5182712}
# Sent: {'tx_id': 10, 'userId': 103, 'amount': 7415.2497110361255, 'timestamp': 1781849957.5192158}
# Sent: {'tx_id': 11, 'userId': 102, 'amount': 1502.3886124753276, 'timestamp': 1781849959.5197854}
# Sent: {'tx_id': 12, 'userId': 103, 'amount': 5384.234052967134, 'timestamp': 1781849961.520441}
# Sent: {'tx_id': 13, 'userId': 101, 'amount': 9258.495017285746, 'timestamp': 1781849963.5211155}
# Sent: {'tx_id': 14, 'userId': 101, 'amount': 5607.390279603762, 'timestamp': 1781849965.5219824}
# Sent: {'tx_id': 15, 'userId': 103, 'amount': 4716.100430259585, 'timestamp': 1781849967.5225103}
# Sent: {'tx_id': 16, 'userId': 104, 'amount': 5550.639012697385, 'timestamp': 1781849969.5229642}
# Sent: {'tx_id': 17, 'userId': 103, 'amount': 1681.7982799835086, 'timestamp': 1781849971.5234957}
# Sent: {'tx_id': 18, 'userId': 103, 'amount': 434.20778006471, 'timestamp': 1781849973.52414}
# Sent: {'tx_id': 19, 'userId': 104, 'amount': 1176.4401188146398, 'timestamp': 1781849975.5250592}
# Sent: {'tx_id': 20, 'userId': 102, 'amount': 1439.3233175008186, 'timestamp': 1781849977.5256433}
# Sent: {'tx_id': 21, 'userId': 103, 'amount': 8235.502694816936, 'timestamp': 1781849979.526191}
# Sent: {'tx_id': 22, 'userId': 104, 'amount': 5838.636261426758, 'timestamp': 1781849981.5236921}
# Sent: {'tx_id': 23, 'userId': 102, 'amount': 4908.5015545657625, 'timestamp': 1781849983.524236}
# Sent: {'tx_id': 24, 'userId': 103, 'amount': 2550.3001402764403, 'timestamp': 1781849985.5250165}
# Sent: {'tx_id': 25, 'userId': 105, 'amount': 3855.1619887428087, 'timestamp': 1781849987.5258152}
# Sent: {'tx_id': 26, 'userId': 105, 'amount': 8252.049790104316, 'timestamp': 1781849989.526696}
# Sent: {'tx_id': 27, 'userId': 103, 'amount': 8752.435670886753, 'timestamp': 1781849991.528057}
# Sent: {'tx_id': 28, 'userId': 103, 'amount': 3278.8555682306724, 'timestamp': 1781849993.5287979}
# Sent: {'tx_id': 29, 'userId': 101, 'amount': 6380.62429661868, 'timestamp': 1781849995.5295396}
# Sent: {'tx_id': 30, 'userId': 104, 'amount': 2694.700990164846, 'timestamp': 1781849997.5302289}
# Sent: {'tx_id': 31, 'userId': 103, 'amount': 4184.37433320318, 'timestamp': 1781849999.5308635}
# Sent: {'tx_id': 32, 'userId': 104, 'amount': 7382.480234345947, 'timestamp': 1781850001.5316825}
# Sent: {'tx_id': 33, 'userId': 103, 'amount': 7981.875872584885, 'timestamp': 1781850003.5331442}
# Sent: {'tx_id': 34, 'userId': 104, 'amount': 2286.154211161392, 'timestamp': 1781850005.5343227}
# Sent: {'tx_id': 35, 'userId': 104, 'amount': 4325.224352712394, 'timestamp': 1781850007.5349908}
# Sent: {'tx_id': 36, 'userId': 104, 'amount': 3352.225114411047, 'timestamp': 1781850009.5367398}
# Sent: {'tx_id': 37, 'userId': 101, 'amount': 8316.149634298903, 'timestamp': 1781850011.5371141}
# Sent: {'tx_id': 38, 'userId': 105, 'amount': 2252.0959121905203, 'timestamp': 1781850013.53759}
# Sent: {'tx_id': 39, 'userId': 105, 'amount': 3746.4575195662587, 'timestamp': 1781850015.5383062}
# Sent: {'tx_id': 40, 'userId': 104, 'amount': 3323.0085080763706, 'timestamp': 1781850017.538938}
# Sent: {'tx_id': 41, 'userId': 101, 'amount': 7933.8405614930325, 'timestamp': 1781850019.5394008}
